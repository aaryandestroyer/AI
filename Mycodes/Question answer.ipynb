# %%
#!pip install langchain==0.0.351
#!pip install --upgrade openai

# %%
#!pip install openai==1.5.0

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI(model_name="gpt-3.5-turbo-instruct")

# %%
our_query = "What is the currency of India?"
completion = llm(our_query)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\U_Project\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~\AppData\Local\anaconda3\envs\U_Project\lib\site-packages\httpcore\_backends\sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File ~\AppData\Local\anaconda3\envs\U_Project\lib\site-packages\httpcore\_backends\sync.py:163, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     162         self._sock.settimeout(timeout)
# --> 163         sock = ssl_context.wrap_socket(
#     164             self._sock, server_hostname=server_hostname
#     165         )
# ...

# %%
print(completion)

# %% [markdown]
# #lets do it by using opensource fee model hugging face

# %%
# !pip install huggingface_hub

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
from langchain.llms import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id = "google/flan-t5-large")

# %%
# The LLM takes a prompt as an input and outputs a completion
our_query = "dollar is currency of"
completion = llm(our_query)

# %%
print(completion)
