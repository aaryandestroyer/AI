# %%
import openai

# %%
mykey="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"

# %%
openai.api_key=mykey

# %%
all_models=openai.models.list()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\GENAI\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~\AppData\Local\anaconda3\envs\GENAI\lib\site-packages\httpcore\_backends\sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File ~\AppData\Local\anaconda3\envs\GENAI\lib\site-packages\httpcore\_backends\sync.py:163, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     162         self._sock.settimeout(timeout)
# --> 163         sock = ssl_context.wrap_socket(
#     164             self._sock, server_hostname=server_hostname
#     165         )
# ...
